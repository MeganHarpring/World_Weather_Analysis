# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | tuatapere
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | chapais
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | marrakesh
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | khatassy
# Processing Record 12 of Set 1 | paramonga
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | geresk
# City not found. Skipping...
# Processing Record 15 of Set 1 | teguise
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | grand gaube
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | praia da vitoria
# Processing Record 24 of Set 1 | isla mujeres
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | husavik
# Processing Record 28 of Set 1 | matay
# Processing Record 29 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 1 | shimoda
# Processing Record 31 of Set 1 | neiafu
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 1 | catuday
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | dabhol
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | cockburn town
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | denpasar
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | tahta
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | darhan
# Processing Record 47 of Set 1 | agirish
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | manicore
# Processing Record 50 of Set 1 | kongolo
# Processing Record 1 of Set 2 | acajutla
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | pandan
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | shirokiy
# Processing Record 8 of Set 2 | kitui
# Processing Record 9 of Set 2 | hovd
# Processing Record 10 of Set 2 | dingle
# Processing Record 11 of Set 2 | abnub
# Processing Record 12 of Set 2 | mbanza-ngungu
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | de aar
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | kokstad
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | gusau
# Processing Record 19 of Set 2 | te anau
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | toora-khem
# Processing Record 22 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | grindavik
# Processing Record 25 of Set 2 | nizhniy odes
# Processing Record 26 of Set 2 | dieppe bay
# City not found. Skipping...
# Processing Record 27 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 28 of Set 2 | mountain home
# Processing Record 29 of Set 2 | bathsheba
# Processing Record 30 of Set 2 | buguruslan
# Processing Record 31 of Set 2 | vengurla
# Processing Record 32 of Set 2 | namatanai
# Processing Record 33 of Set 2 | asau
# Processing Record 34 of Set 2 | dunedin
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | camacha
# Processing Record 37 of Set 2 | pangnirtung
# Processing Record 38 of Set 2 | campos altos
# Processing Record 39 of Set 2 | flinders
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | brande
# Processing Record 43 of Set 2 | solnechnyy
# Processing Record 44 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | northam
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | srikakulam
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 3 | lukovetskiy
# Processing Record 2 of Set 3 | altamont
# Processing Record 3 of Set 3 | mehamn
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | opuwo
# Processing Record 6 of Set 3 | holme
# Processing Record 7 of Set 3 | san quintin
# Processing Record 8 of Set 3 | carutapera
# Processing Record 9 of Set 3 | diamantino
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | waddan
# Processing Record 12 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | camargo
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | yerbogachen
# Processing Record 18 of Set 3 | cherskiy
# Processing Record 19 of Set 3 | vardo
# Processing Record 20 of Set 3 | ippy
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | tunoshna
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | hurricane
# Processing Record 29 of Set 3 | seymchan
# Processing Record 30 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 3 | skjervoy
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | la libertad
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | tsiroanomandidy
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | kutum
# Processing Record 41 of Set 3 | urumqi
# Processing Record 42 of Set 3 | muyezerskiy
# Processing Record 43 of Set 3 | narsaq
# Processing Record 44 of Set 3 | korla
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | sao felix do xingu
# Processing Record 47 of Set 3 | asfi
# Processing Record 48 of Set 3 | butembo
# Processing Record 49 of Set 3 | mahibadhoo
# Processing Record 50 of Set 3 | imuris
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | birjand
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | lemesos
# City not found. Skipping...
# Processing Record 7 of Set 4 | wamba
# Processing Record 8 of Set 4 | zharkent
# Processing Record 9 of Set 4 | vaini
# Processing Record 10 of Set 4 | uchiza
# Processing Record 11 of Set 4 | meulaboh
# Processing Record 12 of Set 4 | lerwick
# Processing Record 13 of Set 4 | jamestown
# Processing Record 14 of Set 4 | san marcos
# Processing Record 15 of Set 4 | yellowknife
# Processing Record 16 of Set 4 | katobu
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | pingliang
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | creel
# Processing Record 22 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 4 | kodiak
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | hervey bay
# Processing Record 28 of Set 4 | mareeba
# Processing Record 29 of Set 4 | mandera
# Processing Record 30 of Set 4 | butaritari
# Processing Record 31 of Set 4 | namibe
# Processing Record 32 of Set 4 | sakaiminato
# Processing Record 33 of Set 4 | mazatlan
# Processing Record 34 of Set 4 | zhigalovo
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | ayagoz
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | naze
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | abha
# Processing Record 41 of Set 4 | corrales
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | foggia
# Processing Record 44 of Set 4 | ishigaki
# Processing Record 45 of Set 4 | iwaki
# Processing Record 46 of Set 4 | kuytun
# Processing Record 47 of Set 4 | ashington
# Processing Record 48 of Set 4 | aloleng
# Processing Record 49 of Set 4 | bonthe
# Processing Record 50 of Set 4 | sangar
# Processing Record 1 of Set 5 | cobija
# Processing Record 2 of Set 5 | guerrero negro
# Processing Record 3 of Set 5 | mount gambier
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | antofagasta
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 9 of Set 5 | sambava
# Processing Record 10 of Set 5 | le port
# Processing Record 11 of Set 5 | chuy
# Processing Record 12 of Set 5 | pangoa
# Processing Record 13 of Set 5 | airai
# Processing Record 14 of Set 5 | ankazobe
# Processing Record 15 of Set 5 | provideniya
# Processing Record 16 of Set 5 | santander
# Processing Record 17 of Set 5 | batemans bay
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | aykhal
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | gariadhar
# Processing Record 22 of Set 5 | noumea
# Processing Record 23 of Set 5 | hay river
# Processing Record 24 of Set 5 | tharad
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | winchester
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | davis
# Processing Record 29 of Set 5 | ndele
# Processing Record 30 of Set 5 | moussoro
# Processing Record 31 of Set 5 | hofn
# Processing Record 32 of Set 5 | chokurdakh
# Processing Record 33 of Set 5 | adana
# Processing Record 34 of Set 5 | dicabisagan
# Processing Record 35 of Set 5 | rincon
# Processing Record 36 of Set 5 | andenes
# Processing Record 37 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 5 | kavaratti
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | sorland
# Processing Record 43 of Set 5 | ordu
# Processing Record 44 of Set 5 | aksay
# Processing Record 45 of Set 5 | tezpur
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | general roca
# Processing Record 49 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 50 of Set 5 | laguna
# Processing Record 1 of Set 6 | basoko
# Processing Record 2 of Set 6 | mar del plata
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | megion
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | camana
# Processing Record 7 of Set 6 | usinsk
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | bontang
# Processing Record 10 of Set 6 | leningradskiy
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 6 | ballina
# Processing Record 14 of Set 6 | bahia blanca
# Processing Record 15 of Set 6 | greytown
# Processing Record 16 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | makkaveyevo
# Processing Record 20 of Set 6 | miajadas
# Processing Record 21 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 6 | sandviken
# Processing Record 23 of Set 6 | hobyo
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | fortuna
# Processing Record 28 of Set 6 | bilma
# Processing Record 29 of Set 6 | antsohihy
# Processing Record 30 of Set 6 | beloha
# Processing Record 31 of Set 6 | luanda
# Processing Record 32 of Set 6 | arauco
# Processing Record 33 of Set 6 | rundu
# Processing Record 34 of Set 6 | huejuquilla el alto
# Processing Record 35 of Set 6 | palmer
# Processing Record 36 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 6 | aksu
# Processing Record 38 of Set 6 | kipit
# Processing Record 39 of Set 6 | becerril
# Processing Record 40 of Set 6 | bandarbeyla
# Processing Record 41 of Set 6 | karratha
# Processing Record 42 of Set 6 | flin flon
# Processing Record 43 of Set 6 | bonnyville
# Processing Record 44 of Set 6 | bonito
# Processing Record 45 of Set 6 | cross lanes
# Processing Record 46 of Set 6 | faya
# Processing Record 47 of Set 6 | krasnorechenskiy
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | bosanska krupa
# Processing Record 50 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 7 | teahupoo
# Processing Record 2 of Set 7 | harper
# Processing Record 3 of Set 7 | ostrovnoy
# Processing Record 4 of Set 7 | tilichiki
# Processing Record 5 of Set 7 | burnie
# Processing Record 6 of Set 7 | ketchikan
# Processing Record 7 of Set 7 | salamiyah
# Processing Record 8 of Set 7 | churapcha
# Processing Record 9 of Set 7 | los llanos de aridane
# Processing Record 10 of Set 7 | kichera
# Processing Record 11 of Set 7 | fort collins
# Processing Record 12 of Set 7 | pochutla
# Processing Record 13 of Set 7 | westport
# Processing Record 14 of Set 7 | rakiv lis
# Processing Record 15 of Set 7 | aklavik
# Processing Record 16 of Set 7 | nanakuli
# Processing Record 17 of Set 7 | yauya
# Processing Record 18 of Set 7 | miles city
# Processing Record 19 of Set 7 | zholymbet
# Processing Record 20 of Set 7 | ust-tsilma
# Processing Record 21 of Set 7 | gizo
# Processing Record 22 of Set 7 | ahipara
# Processing Record 23 of Set 7 | avarua
# Processing Record 24 of Set 7 | samarai
# Processing Record 25 of Set 7 | alamos
# Processing Record 26 of Set 7 | jaguarao
# Processing Record 27 of Set 7 | kirakira
# Processing Record 28 of Set 7 | fairbanks
# Processing Record 29 of Set 7 | saint george
# Processing Record 30 of Set 7 | awjilah
# Processing Record 31 of Set 7 | nushki
# Processing Record 32 of Set 7 | miquelon
# Processing Record 33 of Set 7 | ust-barguzin
# Processing Record 34 of Set 7 | leh
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | puri
# Processing Record 37 of Set 7 | santa rosa
# Processing Record 38 of Set 7 | lons-le-saunier
# Processing Record 39 of Set 7 | turukhansk
# Processing Record 40 of Set 7 | zhuhai
# Processing Record 41 of Set 7 | zhigansk
# Processing Record 42 of Set 7 | nanchang
# Processing Record 43 of Set 7 | poum
# Processing Record 44 of Set 7 | vestmannaeyjar
# Processing Record 45 of Set 7 | naryan-mar
# Processing Record 46 of Set 7 | kieta
# Processing Record 47 of Set 7 | prince rupert
# Processing Record 48 of Set 7 | gat
# Processing Record 49 of Set 7 | henties bay
# Processing Record 50 of Set 7 | tiznit
# Processing Record 1 of Set 8 | ngunguru
# Processing Record 2 of Set 8 | jimo
# Processing Record 3 of Set 8 | buraydah
# Processing Record 4 of Set 8 | mabaruma
# Processing Record 5 of Set 8 | shingu
# Processing Record 6 of Set 8 | avera
# Processing Record 7 of Set 8 | havoysund
# Processing Record 8 of Set 8 | altamira
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | algiers
# Processing Record 11 of Set 8 | luderitz
# Processing Record 12 of Set 8 | zeya
# Processing Record 13 of Set 8 | misratah
# Processing Record 14 of Set 8 | cabo san lucas
# Processing Record 15 of Set 8 | baruun-urt
# Processing Record 16 of Set 8 | strezhevoy
# Processing Record 17 of Set 8 | kwinana
# Processing Record 18 of Set 8 | burica
# City not found. Skipping...
# Processing Record 19 of Set 8 | homer
# Processing Record 20 of Set 8 | nanfeng
# Processing Record 21 of Set 8 | kavieng
# Processing Record 22 of Set 8 | elista
# Processing Record 23 of Set 8 | yulara
# Processing Record 24 of Set 8 | marawi
# Processing Record 25 of Set 8 | longyearbyen
# Processing Record 26 of Set 8 | ostersund
# Processing Record 27 of Set 8 | kerema
# Processing Record 28 of Set 8 | chernyshevskiy
# Processing Record 29 of Set 8 | pisco
# Processing Record 30 of Set 8 | pitimbu
# Processing Record 31 of Set 8 | santa cruz
# Processing Record 32 of Set 8 | beian
# Processing Record 33 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 8 | araripe
# Processing Record 35 of Set 8 | palafrugell
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | yakymivka
# Processing Record 38 of Set 8 | boundiali
# Processing Record 39 of Set 8 | emerald
# Processing Record 40 of Set 8 | guadalupe victoria
# Processing Record 41 of Set 8 | imbituba
# Processing Record 42 of Set 8 | puquio
# Processing Record 43 of Set 8 | rovaniemi
# Processing Record 44 of Set 8 | aurillac
# Processing Record 45 of Set 8 | rawson
# Processing Record 46 of Set 8 | zatoka
# Processing Record 47 of Set 8 | mount isa
# Processing Record 48 of Set 8 | xiaoweizhai
# Processing Record 49 of Set 8 | salalah
# Processing Record 50 of Set 8 | biltine
# Processing Record 1 of Set 9 | chabahar
# Processing Record 2 of Set 9 | anito
# Processing Record 3 of Set 9 | uyuni
# Processing Record 4 of Set 9 | coahuayana
# Processing Record 5 of Set 9 | maxixe
# Processing Record 6 of Set 9 | kindu
# Processing Record 7 of Set 9 | alakurtti
# Processing Record 8 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 9 | pahrump
# Processing Record 10 of Set 9 | tocopilla
# Processing Record 11 of Set 9 | vila velha
# Processing Record 12 of Set 9 | luwuk
# Processing Record 13 of Set 9 | thyboron
# Processing Record 14 of Set 9 | tautira
# Processing Record 15 of Set 9 | boa vista
# Processing Record 16 of Set 9 | linxia
# Processing Record 17 of Set 9 | sapele
# Processing Record 18 of Set 9 | constitucion
# Processing Record 19 of Set 9 | goundam
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | mnogovershinnyy
# Processing Record 22 of Set 9 | nekhayevskiy
# Processing Record 23 of Set 9 | marsh harbour
# Processing Record 24 of Set 9 | vitim
# Processing Record 25 of Set 9 | klaksvik
# Processing Record 26 of Set 9 | petropavlovka
# Processing Record 27 of Set 9 | williston
# Processing Record 28 of Set 9 | aranos
# Processing Record 29 of Set 9 | kruisfontein
# Processing Record 30 of Set 9 | carballo
# Processing Record 31 of Set 9 | nome
# Processing Record 32 of Set 9 | onega
# Processing Record 33 of Set 9 | kangaatsiaq
# Processing Record 34 of Set 9 | lavrentiya
# Processing Record 35 of Set 9 | cassilandia
# Processing Record 36 of Set 9 | huamantla
# Processing Record 37 of Set 9 | wucheng
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | mpika
# Processing Record 41 of Set 9 | mahajanga
# Processing Record 42 of Set 9 | tiksi
# Processing Record 43 of Set 9 | moose jaw
# Processing Record 44 of Set 9 | baykit
# Processing Record 45 of Set 9 | witney
# Processing Record 46 of Set 9 | chulman
# Processing Record 47 of Set 9 | porto novo
# Processing Record 48 of Set 9 | dali
# Processing Record 49 of Set 9 | bedong
# Processing Record 50 of Set 9 | boguchany
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | oistins
# Processing Record 3 of Set 10 | sechura
# Processing Record 4 of Set 10 | ossora
# Processing Record 5 of Set 10 | betafo
# Processing Record 6 of Set 10 | nacala
# Processing Record 7 of Set 10 | prado
# Processing Record 8 of Set 10 | wanning
# Processing Record 9 of Set 10 | belyy yar
# Processing Record 10 of Set 10 | lakatoro
# Processing Record 11 of Set 10 | esso
# Processing Record 12 of Set 10 | rimini
# Processing Record 13 of Set 10 | kankan
# Processing Record 14 of Set 10 | acarau
# Processing Record 15 of Set 10 | biak
# Processing Record 16 of Set 10 | peniche
# Processing Record 17 of Set 10 | nemuro
# Processing Record 18 of Set 10 | mendi
# Processing Record 19 of Set 10 | shar
# Processing Record 20 of Set 10 | teguldet
# Processing Record 21 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 10 | iqaluit
# Processing Record 23 of Set 10 | penzance
# Processing Record 24 of Set 10 | numan
# Processing Record 25 of Set 10 | xichang
# Processing Record 26 of Set 10 | hammerfest
# Processing Record 27 of Set 10 | vao
# Processing Record 28 of Set 10 | lata
# Processing Record 29 of Set 10 | sangin
# Processing Record 30 of Set 10 | port lincoln
# Processing Record 31 of Set 10 | fairlie
# Processing Record 32 of Set 10 | nantucket
# Processing Record 33 of Set 10 | buta
# Processing Record 34 of Set 10 | haines junction
# Processing Record 35 of Set 10 | rosarito
# Processing Record 36 of Set 10 | san felipe
# Processing Record 37 of Set 10 | varkkallai
# Processing Record 38 of Set 10 | gravdal
# Processing Record 39 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 10 | tefe
# Processing Record 41 of Set 10 | abalak
# Processing Record 42 of Set 10 | urengoy
# Processing Record 43 of Set 10 | jalu
# Processing Record 44 of Set 10 | taunggyi
# Processing Record 45 of Set 10 | metro
# Processing Record 46 of Set 10 | benjamin constant
# Processing Record 47 of Set 10 | choix
# Processing Record 48 of Set 10 | sobolevo
# Processing Record 49 of Set 10 | havre-saint-pierre
# Processing Record 50 of Set 10 | catamarca
# Processing Record 1 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 11 | ahtopol
# Processing Record 3 of Set 11 | bokoro
# Processing Record 4 of Set 11 | bonavista
# Processing Record 5 of Set 11 | shelburne
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | rio grande
# Processing Record 8 of Set 11 | aulla
# Processing Record 9 of Set 11 | gornopravdinsk
# Processing Record 10 of Set 11 | guliston
# Processing Record 11 of Set 11 | saint-pierre
# Processing Record 12 of Set 11 | portales
# Processing Record 13 of Set 11 | cap malheureux
# Processing Record 14 of Set 11 | bushehr
# Processing Record 15 of Set 11 | mutoko
# Processing Record 16 of Set 11 | sinnamary
# Processing Record 17 of Set 11 | mayskiy
# Processing Record 18 of Set 11 | liaozhong
# Processing Record 19 of Set 11 | port keats
# Processing Record 20 of Set 11 | faranah
# Processing Record 21 of Set 11 | port augusta
# Processing Record 22 of Set 11 | ternate
# Processing Record 23 of Set 11 | groningen
# Processing Record 24 of Set 11 | filingue
# Processing Record 25 of Set 11 | kaka
# Processing Record 26 of Set 11 | vernon
# Processing Record 27 of Set 11 | alexandria
# Processing Record 28 of Set 11 | eureka
# Processing Record 29 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | rupert
# Processing Record 31 of Set 11 | inhambane
# Processing Record 32 of Set 11 | gushikawa
# Processing Record 33 of Set 11 | saldanha
# Processing Record 34 of Set 11 | colares
# Processing Record 35 of Set 11 | ponta delgada
# Processing Record 36 of Set 11 | ust-ishim
# Processing Record 37 of Set 11 | lasa
# Processing Record 38 of Set 11 | caravelas
# Processing Record 39 of Set 11 | preobrazheniye
# Processing Record 40 of Set 11 | oktyabrskoye
# Processing Record 41 of Set 11 | dudinka
# Processing Record 42 of Set 11 | isakly
# Processing Record 43 of Set 11 | belmonte
# Processing Record 44 of Set 11 | pontalina
# Processing Record 45 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 46 of Set 11 | borovoy
# Processing Record 47 of Set 11 | ust-kuyga
# Processing Record 48 of Set 11 | goderich
# Processing Record 49 of Set 11 | dibulla
# Processing Record 50 of Set 11 | linguere
# Processing Record 1 of Set 12 | teneguiban
# City not found. Skipping...
# Processing Record 2 of Set 12 | pascagoula
# Processing Record 3 of Set 12 | deputatskiy
# Processing Record 4 of Set 12 | kidal
# Processing Record 5 of Set 12 | muscat
# Processing Record 6 of Set 12 | takoradi
# Processing Record 7 of Set 12 | skibbereen
# Processing Record 8 of Set 12 | kroya
# Processing Record 9 of Set 12 | hokitika
# Processing Record 10 of Set 12 | locri
# Processing Record 11 of Set 12 | lazaro cardenas
# Processing Record 12 of Set 12 | lang son
# Processing Record 13 of Set 12 | pagudpud
# Processing Record 14 of Set 12 | paamiut
# Processing Record 15 of Set 12 | krasnooktyabrskiy
# Processing Record 16 of Set 12 | thinadhoo
# Processing Record 17 of Set 12 | komsomolskiy
# Processing Record 18 of Set 12 | portland
# Processing Record 19 of Set 12 | muisne
# Processing Record 20 of Set 12 | suhbaatar
# Processing Record 21 of Set 12 | volga
# Processing Record 22 of Set 12 | yumen
# Processing Record 23 of Set 12 | leshukonskoye
# Processing Record 24 of Set 12 | maceio
# Processing Record 25 of Set 12 | havre
# Processing Record 26 of Set 12 | saposoa
# Processing Record 27 of Set 12 | xining
# Processing Record 28 of Set 12 | ust-koksa
# Processing Record 29 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 12 | saint anthony
# Processing Record 31 of Set 12 | pauini
# Processing Record 32 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 12 | dhidhdhoo
# Processing Record 34 of Set 12 | maraa
# Processing Record 35 of Set 12 | moultrie
# Processing Record 36 of Set 12 | sijunjung
# Processing Record 37 of Set 12 | vanimo
# Processing Record 38 of Set 12 | port macquarie
# Processing Record 39 of Set 12 | anadyr
# Processing Record 40 of Set 12 | ciudad bolivar
# Processing Record 41 of Set 12 | cantanhede
# Processing Record 42 of Set 12 | sola
# Processing Record 43 of Set 12 | manzanillo
# Processing Record 44 of Set 12 | salinopolis
# Processing Record 45 of Set 12 | stawell
# Processing Record 46 of Set 12 | mafinga
# Processing Record 47 of Set 12 | maragogi
# Processing Record 48 of Set 12 | richards bay
# Processing Record 49 of Set 12 | sabha
# Processing Record 50 of Set 12 | lask
# Processing Record 1 of Set 13 | brae
# Processing Record 2 of Set 13 | oyama
# Processing Record 3 of Set 13 | xuddur
# Processing Record 4 of Set 13 | seguin
# Processing Record 5 of Set 13 | igarka
# Processing Record 6 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 13 | slimnic
# Processing Record 8 of Set 13 | pantelho
# Processing Record 9 of Set 13 | rocha
# Processing Record 10 of Set 13 | ambanja
# Processing Record 11 of Set 13 | benxi
# Processing Record 12 of Set 13 | roald
# Processing Record 13 of Set 13 | garowe
# Processing Record 14 of Set 13 | diu
# Processing Record 15 of Set 13 | hilton head island
# Processing Record 16 of Set 13 | san vicente
# Processing Record 17 of Set 13 | whitley bay
# Processing Record 18 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 13 | jiaonan
# Processing Record 20 of Set 13 | waitara
# Processing Record 21 of Set 13 | nizhniy kuranakh
# Processing Record 22 of Set 13 | abu zabad
# Processing Record 23 of Set 13 | phan thiet
# Processing Record 24 of Set 13 | la ronge
# Processing Record 25 of Set 13 | san luis
# Processing Record 26 of Set 13 | pabna
# Processing Record 27 of Set 13 | novosergiyevka
# Processing Record 28 of Set 13 | gamba
# Processing Record 29 of Set 13 | sao gabriel da cachoeira
# Processing Record 30 of Set 13 | sarahan
# Processing Record 31 of Set 13 | uray
# Processing Record 32 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 13 | srednekolymsk
# Processing Record 34 of Set 13 | bereda
# Processing Record 35 of Set 13 | pontianak
# Processing Record 36 of Set 13 | talakan
# Processing Record 37 of Set 13 | westerland
# Processing Record 38 of Set 13 | merauke
# Processing Record 39 of Set 13 | sinazongwe
# Processing Record 40 of Set 13 | galle
# Processing Record 41 of Set 13 | durban
# Processing Record 42 of Set 13 | jeremie
# Processing Record 43 of Set 13 | smoky lake
# Processing Record 44 of Set 13 | ornskoldsvik
# Processing Record 45 of Set 13 | kikwit
# Processing Record 46 of Set 13 | ahuimanu
# Processing Record 47 of Set 13 | khani
# Processing Record 48 of Set 13 | neustadt
# Processing Record 49 of Set 13 | mahuta
# Processing Record 50 of Set 13 | newcastle
# Processing Record 1 of Set 14 | saint-paul
# Processing Record 2 of Set 14 | barcelos
# Processing Record 3 of Set 14 | aswan
# Processing Record 4 of Set 14 | balykshi
# Processing Record 5 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 14 | gao
# Processing Record 7 of Set 14 | lahaina
# Processing Record 8 of Set 14 | sungaipenuh
# Processing Record 9 of Set 14 | tabou
# Processing Record 10 of Set 14 | iskateley
# Processing Record 11 of Set 14 | zhanaozen
# Processing Record 12 of Set 14 | kajaani
# Processing Record 13 of Set 14 | puerto madryn
# Processing Record 14 of Set 14 | alunitdag
# City not found. Skipping...
# Processing Record 15 of Set 14 | pacific grove
# Processing Record 16 of Set 14 | kainantu
# Processing Record 17 of Set 14 | medicine hat
# Processing Record 18 of Set 14 | la serena
# Processing Record 19 of Set 14 | palana
# Processing Record 20 of Set 14 | bud
# Processing Record 21 of Set 14 | hirapur
# Processing Record 22 of Set 14 | vung tau
# Processing Record 23 of Set 14 | macau
# Processing Record 24 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 25 of Set 14 | liverpool
# Processing Record 26 of Set 14 | mayo
# Processing Record 27 of Set 14 | touros
# Processing Record 28 of Set 14 | tynda
# Processing Record 29 of Set 14 | livani
# Processing Record 30 of Set 14 | kurchum
# Processing Record 31 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 14 | beinamar
# Processing Record 33 of Set 14 | russell
# Processing Record 34 of Set 14 | surt
# Processing Record 35 of Set 14 | jacksonville
# Processing Record 36 of Set 14 | shizunai
# Processing Record 37 of Set 14 | longonjo
# Processing Record 38 of Set 14 | varna
# Processing Record 39 of Set 14 | ventspils
# Processing Record 40 of Set 14 | ouro preto do oeste
# Processing Record 41 of Set 14 | ust-ilimsk
# Processing Record 42 of Set 14 | ranfurly
# Processing Record 43 of Set 14 | margate
# Processing Record 44 of Set 14 | horki
# Processing Record 45 of Set 14 | boende
# Processing Record 46 of Set 14 | gleisdorf
# Processing Record 47 of Set 14 | mawlaik
# Processing Record 48 of Set 14 | orzu
# Processing Record 49 of Set 14 | san bartolome
# Processing Record 50 of Set 14 | honningsvag
# Processing Record 1 of Set 15 | fort-shevchenko
# Processing Record 2 of Set 15 | mugur-aksy
# Processing Record 3 of Set 15 | talara
# Processing Record 4 of Set 15 | bartica
# Processing Record 5 of Set 15 | alice springs
# Processing Record 6 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 15 | yeppoon
# Processing Record 8 of Set 15 | bilibino
# Processing Record 9 of Set 15 | maniitsoq
# Processing Record 10 of Set 15 | disraeli
# Processing Record 11 of Set 15 | terrace
# Processing Record 12 of Set 15 | kawalu
# Processing Record 13 of Set 15 | viedma
# Processing Record 14 of Set 15 | yingzhong
# City not found. Skipping...
# Processing Record 15 of Set 15 | sydney
# Processing Record 16 of Set 15 | soavinandriana
# Processing Record 17 of Set 15 | boromo
# Processing Record 18 of Set 15 | kostomuksha
# Processing Record 19 of Set 15 | bagdarin
# Processing Record 20 of Set 15 | kampot
# Processing Record 21 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 15 | tulum
# Processing Record 23 of Set 15 | mangrol
# Processing Record 24 of Set 15 | assiniboia
# Processing Record 25 of Set 15 | volot
# Processing Record 26 of Set 15 | kitale
# Processing Record 27 of Set 15 | cortez
# Processing Record 28 of Set 15 | perur
# Processing Record 29 of Set 15 | khasan
# Processing Record 30 of Set 15 | porto walter
# Processing Record 31 of Set 15 | patea
# Processing Record 32 of Set 15 | necochea
# Processing Record 33 of Set 15 | hirtshals
# Processing Record 34 of Set 15 | huanren
# Processing Record 35 of Set 15 | plettenberg bay
# Processing Record 36 of Set 15 | ambatondrazaka
# Processing Record 37 of Set 15 | ardakan
# Processing Record 38 of Set 15 | gorontalo
# Processing Record 39 of Set 15 | araouane
# Processing Record 40 of Set 15 | majene
# Processing Record 41 of Set 15 | spencer
# Processing Record 42 of Set 15 | valparaiso
# Processing Record 43 of Set 15 | letlhakane
# Processing Record 44 of Set 15 | bayji
# Processing Record 45 of Set 15 | lorengau
# Processing Record 46 of Set 15 | hirara
# Processing Record 47 of Set 15 | warsaw
# Processing Record 48 of Set 15 | hot springs
# Processing Record 49 of Set 15 | barillas
# Processing Record 50 of Set 15 | bourail
# Processing Record 1 of Set 16 | mambajao
# Processing Record 2 of Set 16 | bridgetown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     41.11        87          75
# 1  Severo-Kurilsk      RU  50.6789  156.1250     35.20        99         100
# 2       Tuatapere      NZ -46.1333  167.6833     61.83        72          37
# 3        Khatanga      RU  71.9667  102.5000     21.97        94         100
# 4         Chapais      CA  49.7834  -74.8492     42.58        96         100
# 5        Olafsvik      IS  64.8945  -23.7142     33.85        63          64
# 6       Marrakesh      MA  31.6315   -8.0083     57.27        72          40
# 7          Hasaki      JP  35.7333  140.8333     75.29        58           0
# 8  Port Elizabeth      ZA -33.9180   25.5701     63.32        95           0
# 9  Ribeira Grande      PT  38.5167  -28.7000     62.33        88          53
#
#    Wind Speed          Current Description
# 0       27.63  light intensity shower rain
# 1       10.94                   light snow
# 2        2.17             scattered clouds
# 3        8.46                   light snow
# 4        9.95              overcast clouds
# 5        9.57                broken clouds
# 6        5.75             scattered clouds
# 7       21.77                    clear sky
# 8        9.22                    clear sky
# 9       11.34                broken clouds

# %%
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
